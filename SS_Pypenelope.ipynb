# %%
import pyautogui
import time
import os 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np

pyautogui.FAILSAFE = True # stop code condition
## Positions on the screen
PosBuscar=(90, 749)
PosFile=(214,128)
PosOpen=(239,156)
PosRun=(495,149)
PosSavcsv = (600,458)
Poscsv=(299,146)

# the paths of the simulation files is defined 
pathAllPC1='C:\\PyPen2\\TiNonSi_Batch12kv_30kv_50nm_1000nm'
pathAllPC2='C:\\pypenelope\\SSTotal_20to4000nm'

allfiles = os.listdir(pathAllPC2)

# %%
def dividelist(l,number):
    d = int(len(l)/number)
    print(len(l)%number)
    r = []
    for i in range(number):
        r.append(l[d*i:d*(1+i)])
    return r
Lruns = dividelist(allfiles,4)
# Out:
# 0

# %%
time.sleep(5)
#running the simulations
tiniT=time.time()
tim=[]
i=0
for runs in Lruns:
    for names in runs:#listo
        i=i+1
        t0=time.time()
        pyautogui.moveTo(PosBuscar)
        pyautogui.click()
        time.sleep(0.5)
        pyautogui.write('Pypenelope', interval=0.1)
        pyautogui.press('enter')
        # en ese momento se abrira el software pypenelope
        time.sleep(2)
        pyautogui.moveTo(PosFile)
        pyautogui.click()
        pyautogui.moveTo(PosOpen)
        time.sleep(1)
        pyautogui.click()
        pyautogui.write(pathAllPC2+'\\'+names,interval=0.05)
        pyautogui.press('enter')
        textaux = os.listdir(pathAllPC2+'\\'+names)
        text = [f for f in textaux if f[-4:] == '.xml'][0]
        ## corrección que solo abra el tipo de archivos xml
        pyautogui.write(text)
        pyautogui.press('enter')
        time.sleep(2.5)
        pyautogui.moveTo(PosRun)
        time.sleep(2.5)
        #pyautogui.click()
        pyautogui.click()
        pyautogui.press('enter')
        print(f'Empieza la espera parcial de 2.5 min ciclo {i}')
        time.sleep(60*1.5)
        tff=time.time()
        print(tff-t0)
        tim.append(tff-t0)
        plt.plot(tim)
        plt.title('Evolucion del tiempo de ejecución')
    print('primer ciclo terminado')
    tf=time.time()
    delta=tf-t0
    print(delta)
    time.sleep(60*3)
# Out:
# Empieza la espera parcial de 2.5 min ciclo 1
# 106.41035795211792
# Empieza la espera parcial de 2.5 min ciclo 2
# 106.67801642417908
# Empieza la espera parcial de 2.5 min ciclo 3
# 107.44384765625
# Empieza la espera parcial de 2.5 min ciclo 4
# 112.3692090511322
# Empieza la espera parcial de 2.5 min ciclo 5
# 191.15954113006592
# Empieza la espera parcial de 2.5 min ciclo 6
# 117.86240839958191
# Empieza la espera parcial de 2.5 min ciclo 7
# 114.67846512794495
# Empieza la espera parcial de 2.5 min ciclo 8
# 114.86690211296082
# Empieza la espera parcial de 2.5 min ciclo 9
# 180.95245361328125
# Empieza la espera parcial de 2.5 min ciclo 10
# 124.26506662368774
# Empieza la espera parcial de 2.5 min ciclo 11
# 115.54680919647217
# Empieza la espera parcial de 2.5 min ciclo 12
# 109.1958658695221
# Empieza la espera parcial de 2.5 min ciclo 13
# 110.6232328414917
# Empieza la espera parcial de 2.5 min ciclo 14
# 110.79855513572693
# Empieza la espera parcial de 2.5 min ciclo 15
# 110.66520071029663
# Empieza la espera parcial de 2.5 min ciclo 16
# 192.62731909751892
# Empieza la espera parcial de 2.5 min ciclo 17
# 118.79344892501831
# Empieza la espera parcial de 2.5 min ciclo 18
# 115.61785554885864
# Empieza la espera parcial de 2.5 min ciclo 19
# 112.58389234542847
# Empieza la espera parcial de 2.5 min ciclo 20
# 181.0147955417633
# Empieza la espera parcial de 2.5 min ciclo 21
# 123.45037937164307
# Empieza la espera parcial de 2.5 min ciclo 22
# 116.14903497695923
# Empieza la espera parcial de 2.5 min ciclo 23
# 116.07148933410645
# Empieza la espera parcial de 2.5 min ciclo 24
# 173.29932355880737
# Empieza la espera parcial de 2.5 min ciclo 25
# 126.16594862937927
# Empieza la espera parcial de 2.5 min ciclo 26
# 117.22978162765503
# Empieza la espera parcial de 2.5 min ciclo 27
# 116.5869734287262
# Empieza la espera parcial de 2.5 min ciclo 28
# 168.65395092964172
# Empieza la espera parcial de 2.5 min ciclo 29
# 129.67044258117676
# Empieza la espera parcial de 2.5 min ciclo 30
# 117.74336099624634
# Empieza la espera parcial de 2.5 min ciclo 31
# 116.5102927684784
# primer ciclo terminado
# 116.51231026649475
# Empieza la espera parcial de 2.5 min ciclo 32
# 107.865793466568
# Empieza la espera parcial de 2.5 min ciclo 33
# 107.0082938671112
# Empieza la espera parcial de 2.5 min ciclo 34
# 107.04155158996582
# Empieza la espera parcial de 2.5 min ciclo 35
# 110.83416676521301
# Empieza la espera parcial de 2.5 min ciclo 36
# 194.68272709846497
# Empieza la espera parcial de 2.5 min ciclo 37
# 116.24289131164551
# Empieza la espera parcial de 2.5 min ciclo 38
# 114.19994401931763
# Empieza la espera parcial de 2.5 min ciclo 39
# 113.92028641700745
# Empieza la espera parcial de 2.5 min ciclo 40
# 183.57443046569824
# Empieza la espera parcial de 2.5 min ciclo 41
# 120.41884303092957
# Empieza la espera parcial de 2.5 min ciclo 42
# 116.2802963256836
# Empieza la espera parcial de 2.5 min ciclo 43
# 117.15805983543396
# Empieza la espera parcial de 2.5 min ciclo 44
# 174.28291201591492
# Empieza la espera parcial de 2.5 min ciclo 45
# 125.24743890762329
# Empieza la espera parcial de 2.5 min ciclo 46
# 116.57956051826477
# Empieza la espera parcial de 2.5 min ciclo 47
# 116.81460213661194
# Empieza la espera parcial de 2.5 min ciclo 48
# 171.42544412612915
# Empieza la espera parcial de 2.5 min ciclo 49
# 126.60808944702148
# Empieza la espera parcial de 2.5 min ciclo 50
# 117.86619734764099
# Empieza la espera parcial de 2.5 min ciclo 51
# 116.94743871688843
# Empieza la espera parcial de 2.5 min ciclo 52
# 166.70376205444336
# Empieza la espera parcial de 2.5 min ciclo 53
# 129.82591462135315
# Empieza la espera parcial de 2.5 min ciclo 54
# 110.49875974655151
# Empieza la espera parcial de 2.5 min ciclo 55
# 110.54514241218567
# Empieza la espera parcial de 2.5 min ciclo 56
# 110.65588521957397
# Empieza la espera parcial de 2.5 min ciclo 57
# 110.55175518989563
# Empieza la espera parcial de 2.5 min ciclo 58
# 192.54759788513184
# Empieza la espera parcial de 2.5 min ciclo 59
# 116.75228691101074
# Empieza la espera parcial de 2.5 min ciclo 60
# 116.18101739883423
# Empieza la espera parcial de 2.5 min ciclo 61
# 113.99909996986389
# Empieza la espera parcial de 2.5 min ciclo 62
# 180.5396807193756
# primer ciclo terminado
# 180.54167652130127
# Empieza la espera parcial de 2.5 min ciclo 63
# 107.1570975780487
# Empieza la espera parcial de 2.5 min ciclo 64
# 106.80064368247986
# Empieza la espera parcial de 2.5 min ciclo 65
# 106.94552040100098
# Empieza la espera parcial de 2.5 min ciclo 66
# 110.06540489196777
# Empieza la espera parcial de 2.5 min ciclo 67
# 197.3773272037506
# Empieza la espera parcial de 2.5 min ciclo 68
# 115.97973275184631
# Empieza la espera parcial de 2.5 min ciclo 69
# 115.21857452392578
# Empieza la espera parcial de 2.5 min ciclo 70
# 112.9407148361206
# Empieza la espera parcial de 2.5 min ciclo 71
# 184.69589376449585
# Empieza la espera parcial de 2.5 min ciclo 72
# 120.41664600372314
# Empieza la espera parcial de 2.5 min ciclo 73
# 116.7213990688324
# Empieza la espera parcial de 2.5 min ciclo 74
# 116.63629722595215
# Empieza la espera parcial de 2.5 min ciclo 75
# 175.1933057308197
# Empieza la espera parcial de 2.5 min ciclo 76
# 124.60854268074036
# Empieza la espera parcial de 2.5 min ciclo 77
# 117.37210750579834
# Empieza la espera parcial de 2.5 min ciclo 78
# 117.12074613571167
# Empieza la espera parcial de 2.5 min ciclo 79
# 167.91454815864563
# Empieza la espera parcial de 2.5 min ciclo 80
# 130.6479253768921
# Empieza la espera parcial de 2.5 min ciclo 81
# 120.2433876991272
# Empieza la espera parcial de 2.5 min ciclo 82
# 116.96583366394043
# Empieza la espera parcial de 2.5 min ciclo 83
# 161.8892514705658
# Empieza la espera parcial de 2.5 min ciclo 84
# 133.3258044719696
# Empieza la espera parcial de 2.5 min ciclo 85
# 120.9266562461853
# Empieza la espera parcial de 2.5 min ciclo 86
# 111.72162318229675
# Empieza la espera parcial de 2.5 min ciclo 87
# 111.77313566207886
# Empieza la espera parcial de 2.5 min ciclo 88
# 111.35200953483582
# Empieza la espera parcial de 2.5 min ciclo 89
# 111.9486198425293
# Empieza la espera parcial de 2.5 min ciclo 90
# 189.03897261619568
# Empieza la espera parcial de 2.5 min ciclo 91
# 120.91293907165527
# Empieza la espera parcial de 2.5 min ciclo 92
# 116.4679548740387
# Empieza la espera parcial de 2.5 min ciclo 93
# 114.55598950386047
# primer ciclo terminado
# 114.55598950386047
# Empieza la espera parcial de 2.5 min ciclo 94
# 112.97622895240784
# Empieza la espera parcial de 2.5 min ciclo 95
# 111.98963713645935
# Empieza la espera parcial de 2.5 min ciclo 96
# 112.03893518447876
# Empieza la espera parcial de 2.5 min ciclo 97
# 111.90377926826477
# Empieza la espera parcial de 2.5 min ciclo 98
# 188.8842852115631
# Empieza la espera parcial de 2.5 min ciclo 99
# 119.20421528816223
# Empieza la espera parcial de 2.5 min ciclo 100
# 115.53228855133057
# Empieza la espera parcial de 2.5 min ciclo 101
# 116.12584376335144
# Empieza la espera parcial de 2.5 min ciclo 102
# 177.23647499084473
# Empieza la espera parcial de 2.5 min ciclo 103
# 123.90830898284912
# Empieza la espera parcial de 2.5 min ciclo 104
# 117.37066459655762
# Empieza la espera parcial de 2.5 min ciclo 105
# 117.48298907279968
# Empieza la espera parcial de 2.5 min ciclo 106
# 168.27585077285767
# Empieza la espera parcial de 2.5 min ciclo 107
# 130.4125907421112
# Empieza la espera parcial de 2.5 min ciclo 108
# 118.4245285987854
# Empieza la espera parcial de 2.5 min ciclo 109
# 117.3467960357666
# Empieza la espera parcial de 2.5 min ciclo 110
# 164.38384342193604
# Empieza la espera parcial de 2.5 min ciclo 111
# 132.6226077079773
# Empieza la espera parcial de 2.5 min ciclo 112
# 118.85691165924072
# Empieza la espera parcial de 2.5 min ciclo 113
# 110.75749230384827
# Empieza la espera parcial de 2.5 min ciclo 114
# 111.7716474533081
# Empieza la espera parcial de 2.5 min ciclo 115
# 111.3833966255188
# Empieza la espera parcial de 2.5 min ciclo 116
# 111.95600533485413
# Empieza la espera parcial de 2.5 min ciclo 117
# 189.3390016555786
# Empieza la espera parcial de 2.5 min ciclo 118
# 120.62968420982361
# Empieza la espera parcial de 2.5 min ciclo 119
# 117.25359082221985
# Empieza la espera parcial de 2.5 min ciclo 120
# 115.0655517578125
# Empieza la espera parcial de 2.5 min ciclo 121
# 176.45921111106873
# Empieza la espera parcial de 2.5 min ciclo 122
# 125.4958016872406
# Empieza la espera parcial de 2.5 min ciclo 123
# 117.60950326919556
# Empieza la espera parcial de 2.5 min ciclo 124
# 117.69890403747559
# primer ciclo terminado
# 117.70089888572693

# %%
np.array(tim).sum()/3600
# Out:
# 5.479748186005486

# %%
j=0
tiniT=time.time()
for names in vaciosn:
    j+=1
    if j==1:
        t0=time.time()
        pyautogui.moveTo(PosBuscar)
        pyautogui.click()
        time.sleep(0.5)
        pyautogui.write('Pypenelope', interval=0.1)
        pyautogui.press('enter')
        # en ese momento se abrira el software pypenelope
        time.sleep(2)
        pyautogui.moveTo(PosFile)
        pyautogui.click()
        pyautogui.moveTo(PosOpen)
        time.sleep(1)
        pyautogui.click()
        pyautogui.write(pathAllPC2+'\\'+names,interval=0.01)
        pyautogui.press('enter')
        textaux = os.listdir(pathAllPC2+'\\'+names)
        text = [f for f in textaux if f[-4:] == '.xml'][0]
        ## corrección que solo abra el tipo de archivos xml
        pyautogui.write(text)
        pyautogui.press('enter')
        time.sleep(2)
        pyautogui.moveTo(Poscsv)
        pyautogui.click()
        pyautogui.moveTo(PosSavcsv)
        time.sleep(0.1)
        pyautogui.click()
        pyautogui.press('delete',presses=70,interval=0.01)
        pyautogui.write(pathAllPC2+'\\'+names,interval=0.01)
        pyautogui.press('enter')
        time.sleep(1)
        pyautogui.press('enter')
        print(f'listo {names}, el número {j}')
    else:
        time.sleep(2)
        pyautogui.moveTo(PosFile)
        pyautogui.click()
        pyautogui.moveTo(PosOpen)
        time.sleep(1)
        pyautogui.click()
        pyautogui.write(pathAllPC2+'\\'+names,interval=0.01)
        pyautogui.press('enter')
        textaux = os.listdir(pathAllPC2+'\\'+names)
        text = [f for f in textaux if f[-4:] == '.xml'][0]
        ## corrección que solo abra el tipo de archivos xml
        pyautogui.write(text)
        pyautogui.press('enter')
        time.sleep(3)
        pyautogui.moveTo(Poscsv)
        pyautogui.click()
        pyautogui.moveTo(PosSavcsv)
        time.sleep(0.2)
        pyautogui.click()
        pyautogui.click()
        pyautogui.press('delete',presses=100,interval=0.01)
        pyautogui.write(pathAllPC2+'\\'+names,interval=0.01)
        pyautogui.press('enter')
        time.sleep(1)
        pyautogui.press('enter')
        print(f'listo {names}, el número {j}')

tff=time.time()
print(tff-tiniT)
tim.append(tff-tiniT)
# Out:
# listo batch_layer_0_thickness=120.0nm_beam_energy=24.0keV, el número 1
# listo batch_layer_0_thickness=1750.0nm_beam_energy=24.0keV, el número 2
# listo batch_layer_0_thickness=240.0nm_beam_energy=12.0keV, el número 3
# listo batch_layer_0_thickness=2500.0nm_beam_energy=18.0keV, el número 4
# listo batch_layer_0_thickness=400.0nm_beam_energy=12.0keV, el número 5
# listo batch_layer_0_thickness=700.0nm_beam_energy=24.0keV, el número 6
# listo batch_layer_0_thickness=900.0nm_beam_energy=30.0keV, el número 7
# listo batch_layer_0_thickness=900.0nm_beam_energy=12.0keV, el número 8
# listo batch_layer_0_thickness=900.0nm_beam_energy=18.0keV, el número 9
# listo batch_layer_0_thickness=900.0nm_beam_energy=24.0keV, el número 10
# listo batch_layer_0_thickness=900.0nm_beam_energy=30.0keV, el número 11
# 150.85294771194458

# %%
vacios=[]
dic1={}
dic2={}
dic3={}
for names in allfiles:
    textaux = os.listdir(pathAllPC2+'\\'+names)
    text = [f for f in textaux if f[:9] == 'intensity']
    if text == []:
        vacios.append(names)
    else:
        newstr = ''.join((ch if ch in '0123456789' else ' ') for ch in names)#toma los numeros del nombre del archivo
        listOfNumbers = [int(i) for i in newstr.split()]#ubica los números dentro de un diccionario
        e0 = listOfNumbers[3]
        th = listOfNumbers[1]
        dfd1=pd.read_csv(pathAllPC2+'\\'+names+'\\'+'intensity_1.csv')
        dfd1.columns = ['Z', 'IUPAC', 'Siegbahn', 'Source subshell', 'Destination subshell',
       'Energy (kev)', 'P', 'P_unc', 'C', 'C_unc', 'B', 'B_unc', 'TF',
       'TF_unc', 'Total', 'T_unc']
        dic1[(e0,th)]=dfd1
        
        dfd2=pd.read_csv(pathAllPC2+'\\'+names+'\\'+'intensity_2.csv')
        dfd2.columns = ['Z', 'IUPAC', 'Siegbahn', 'Source subshell', 'Destination subshell',
       'Energy (kev)', 'P', 'P_unc', 'C', 'C_unc', 'B', 'B_unc', 'TF',
       'TF_unc', 'Total', 'T_unc']
        dic2[(e0,th)]=dfd2
        
        dfd3=pd.read_csv(pathAllPC2+'\\'+names+'\\'+'intensity_3.csv')
        dfd3.columns = ['Z', 'IUPAC', 'Siegbahn', 'Source subshell', 'Destination subshell',
       'Energy (kev)', 'P', 'P_unc', 'C', 'C_unc', 'B', 'B_unc', 'TF',
       'TF_unc', 'Total', 'T_unc']
        dic3[(e0,th)]=dfd3

# %%
def tratDatosSS(dic):
    """
    FUnción que retorna un dataframe con los datos de la intensidad y el Iratio*
    """
    energy, thickness = [], []
    Tik, Nk, SSk = [], [], []
    for key, value in dic.items():
        energy.append(key[0])
        thickness.append(key[1])
        dfaux=dic[key][(dic[key].Siegbahn=='Ka1') | (dic[key].Siegbahn=='Ka2') | (dic[key].Siegbahn=='Kb1')|(dic[key].Siegbahn=='Kb2')]
        Tik.append(dfaux[dfaux.Z==22].Total.sum())
        dfaux[dfaux.Z==22].T_unc.sum()
        SSk.append(dfaux[dfaux.Z==26].Total.sum())
        dfaux[dfaux.Z==26].T_unc.sum()
    dic_data={'Energy':energy,'Thickness':thickness,'Tik':Tik,'SSk':SSk}
    dft=pd.DataFrame(dic_data)
    dft['I_ratio']=dft['I_ratio']=dft.SSk/dft.Tik
    df1=dft.set_index(['Energy','Thickness']).sort_index()
    return df1

# %%
vacios
# Out:
# []

# %%
dfdet1=tratDatosSS(dic1)
dfdet2=tratDatosSS(dic2)
dfdet3=tratDatosSS(dic3)

# %%
dfdet1.to_excel(pathAllPC2+'\\'+'TiNonSS_det1_pypen.xlsx')
dfdet2.to_excel(pathAllPC2+'\\'+'TiNonSS_det2_pypen.xlsx')
dfdet3.to_excel(pathAllPC2+'\\'+'TiNonSS_det3_pypen.xlsx')

# %%
for e in range(12,31,6):
    #plt.plot(dfdet1.loc[e].I_ratio,'r*',label=f'det1 {e}kV')
    #plt.plot(dfdet2.loc[e].I_ratio,'bo-',label=f'det2 {e}kV')
    plt.plot(dfdet1.loc[e].I_ratio,'.-',label=f'det3 {e}kV')
    plt.yscale('log')
    plt.xscale('log')
    #plt.xlim(700,1200)
plt.legend()

# %%
allfiles
# Out:
# ['batch_layer_0_thickness=100.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=100.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=100.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=100.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=1000.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=1000.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=1000.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=1000.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=120.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=120.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=120.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=120.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=1250.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=1250.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=1250.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=1250.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=140.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=140.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=140.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=140.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=1500.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=1500.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=1500.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=1500.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=160.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=160.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=160.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=160.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=1750.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=1750.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=1750.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=1750.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=180.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=180.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=180.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=180.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=20.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=20.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=20.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=20.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=200.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=200.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=200.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=200.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=2000.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=2000.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=2000.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=2000.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=220.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=220.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=220.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=220.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=240.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=240.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=240.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=240.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=250.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=250.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=250.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=250.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=2500.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=2500.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=2500.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=2500.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=300.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=300.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=300.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=300.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=3000.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=3000.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=3000.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=3000.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=350.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=350.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=350.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=350.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=3500.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=3500.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=3500.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=3500.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=40.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=40.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=40.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=40.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=400.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=400.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=400.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=400.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=4000.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=4000.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=4000.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=4000.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=450.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=450.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=450.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=450.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=500.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=500.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=500.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=500.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=60.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=60.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=60.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=60.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=600.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=600.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=600.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=600.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=700.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=700.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=700.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=700.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=80.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=80.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=80.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=80.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=800.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=800.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=800.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=800.0nm_beam_energy=30.0keV',
#  'batch_layer_0_thickness=900.0nm_beam_energy=12.0keV',
#  'batch_layer_0_thickness=900.0nm_beam_energy=18.0keV',
#  'batch_layer_0_thickness=900.0nm_beam_energy=24.0keV',
#  'batch_layer_0_thickness=900.0nm_beam_energy=30.0keV']

# %%
vaciosn = vacios + ['batch_layer_0_thickness=900.0nm_beam_energy=12.0keV',
'batch_layer_0_thickness=900.0nm_beam_energy=18.0keV',
 'batch_layer_0_thickness=900.0nm_beam_energy=24.0keV',
 'batch_layer_0_thickness=900.0nm_beam_energy=30.0keV']

# %%
len(vaciosn)
# Out:
# 11

# %%
time.sleep(5)
#running the simulations
tiniT=time.time()
tim=[]
i=0
for names in vaciosn:#listo
    i=i+1
    t0=time.time()
    pyautogui.moveTo(PosBuscar)
    pyautogui.click()
    time.sleep(0.5)
    pyautogui.write('Pypenelope', interval=0.1)
    pyautogui.press('enter')
    # en ese momento se abrira el software pypenelope
    time.sleep(2)
    pyautogui.moveTo(PosFile)
    pyautogui.click()
    pyautogui.moveTo(PosOpen)
    time.sleep(1)
    pyautogui.click()
    pyautogui.write(pathAllPC2+'\\'+names,interval=0.01)
    pyautogui.press('enter')
    textaux = os.listdir(pathAllPC2+'\\'+names)
    text = [f for f in textaux if f[-4:] == '.xml'][0]
    ## corrección que solo abra el tipo de archivos xml
    pyautogui.write(text,interval=0.01)
    pyautogui.press('enter')
    time.sleep(2.5)
    pyautogui.moveTo(PosRun)
    time.sleep(2.5)
    #pyautogui.click()
    pyautogui.click()
    pyautogui.press('enter')
    print(f'Empieza la espera parcial de 2.5 min ciclo {i}')
    time.sleep(60*1.5)
    tff=time.time()
    print(tff-t0)
    tim.append(tff-t0)
    plt.plot(tim)
    plt.title('Evolucion del tiempo de ejecución')
print('primer ciclo terminado')
tf=time.time()
delta=tf-t0
print(delta)
# Out:
# Empieza la espera parcial de 2.5 min ciclo 1
# 104.06343626976013
# Empieza la espera parcial de 2.5 min ciclo 2
# 104.5695378780365
# Empieza la espera parcial de 2.5 min ciclo 3
# 105.37031960487366
# Empieza la espera parcial de 2.5 min ciclo 4
# 108.75541853904724
# Empieza la espera parcial de 2.5 min ciclo 5
# 158.33145689964294
# Empieza la espera parcial de 2.5 min ciclo 6
# 152.3721902370453
# Empieza la espera parcial de 2.5 min ciclo 7
# 112.73502397537231
# Empieza la espera parcial de 2.5 min ciclo 8
# 112.99479413032532
# Empieza la espera parcial de 2.5 min ciclo 9
# 159.86691570281982
# Empieza la espera parcial de 2.5 min ciclo 10
# 137.4555368423462
# Empieza la espera parcial de 2.5 min ciclo 11
# 113.84165573120117
# primer ciclo terminado
# 113.84367299079895
